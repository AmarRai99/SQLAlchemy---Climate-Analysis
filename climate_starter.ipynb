# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 from matplotlib import style
#       3 style.use('fivethirtyeight')
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py:2369, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2367     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2368 with self.builtin_trap:
# -> 2369     result = fn(*args, **kwargs)
#    2370 return result
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/magics/pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
# ...

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
engine
# Out:
# Engine(sqlite:///Resources/hawaii.sqlite)

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
inspector = inspect(engine)
tables = inspector.get_table_names()
tables
# Out:
# ['measurement', 'station']

# %%
# Create our session (link) from Python to the DB
for table in tables:
    print(table)
    for column in inspector.get_columns(table):
        print(column["name"], column["type"])
    print()
# Out:
# measurement
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT
#
# station
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Save references to each table
measurement = Base.classes.measurement
measurement

station = Base.classes.station
station
# Out:
# sqlalchemy.ext.automap.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
for row in session.query(measurement.id, measurement.station, measurement.date, measurement.prcp, measurement.tobs):
    print(row)
    
for row in session.query(station.id, station.station, station.name, station.latitude, station.longitude, station.elevation):
    print(row)
# Out:
# (1, 'USC00519397', '2010-01-01', 0.08, 65.0)
# (2, 'USC00519397', '2010-01-02', 0.0, 63.0)
# (3, 'USC00519397', '2010-01-03', 0.0, 74.0)
# (4, 'USC00519397', '2010-01-04', 0.0, 76.0)
# (5, 'USC00519397', '2010-01-06', None, 73.0)
# (6, 'USC00519397', '2010-01-07', 0.06, 70.0)
# (7, 'USC00519397', '2010-01-08', 0.0, 64.0)
# (8, 'USC00519397', '2010-01-09', 0.0, 68.0)
# (9, 'USC00519397', '2010-01-10', 0.0, 73.0)
# (10, 'USC00519397', '2010-01-11', 0.01, 64.0)
# (11, 'USC00519397', '2010-01-12', 0.0, 61.0)
# (12, 'USC00519397', '2010-01-14', 0.0, 66.0)
# (13, 'USC00519397', '2010-01-15', 0.0, 65.0)
# (14, 'USC00519397', '2010-01-16', 0.0, 68.0)
# (15, 'USC00519397', '2010-01-17', 0.0, 64.0)
# (16, 'USC00519397', '2010-01-18', 0.0, 72.0)
# (17, 'USC00519397', '2010-01-19', 0.0, 66.0)
# (18, 'USC00519397', '2010-01-20', 0.0, 66.0)
# (19, 'USC00519397', '2010-01-21', 0.0, 69.0)
# (20, 'USC00519397', '2010-01-22', 0.0, 67.0)
# (21, 'USC00519397', '2010-01-23', 0.0, 67.0)
# ...

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.

most_recent = session.query(func.max(measurement.date)).first()[0]

print(f"The most recent date in the dataset is {most_recent}")


# Calculate the date one year from the last date in data set.


most_rec = dt.datetime.strptime(most_recent, '%Y-%m-%d') - dt.timedelta(days=365)
most_rec
# Out:
# The most recent date in the dataset is 2017-08-23
# datetime.datetime(2016, 8, 23, 0, 0)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 


# Perform a query to retrieve the data and precipitation scores
precip = session.query(measurement.date, measurement.prcp).filter(measurement.date >= most_rec).all()
precip

# Save the query results as a Pandas DataFrame and set the index to the date column
precip_df = pd.DataFrame(precip, columns=['date', 'precipitation'])


# Sort the dataframe by date
precip_df = precip_df.sort_values("date")


# Use Pandas Plotting with Matplotlib to plot the data
precip_df
# Out:
#             date  precipitation
# 0     2016-08-24           0.08
# 1006  2016-08-24            NaN
# 1524  2016-08-24           2.15
# 702   2016-08-24           2.28
# 360   2016-08-24           2.15
# ...          ...            ...
# 1522  2017-08-22           0.00
# 1523  2017-08-23           0.08
# 359   2017-08-23           0.00
# 1005  2017-08-23           0.00
# 2222  2017-08-23           0.45
#
# [2223 rows x 2 columns]

# %%
# Use Pandas Plotting with Matplotlib to plot the data

precip_df.plot(x='date', y='precipitation', rot=90, figsize=(13, 8))
plt.xlabel("Date")
plt.ylabel("Inches")
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data

precip_df.describe()
# Out:
#        precipitation
# count    2015.000000
# mean        0.176462
# std         0.460288
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset

how_many_stations = session.query(station).count()
how_many_stations
# Out:
# 9

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.

query= session.query(measurement.station, measurement.date).all()
active_stations_df = pd.DataFrame(query, columns=['station', 'frequency'])

# %%
active_stations_df = active_stations_df.groupby(['station']).count().sort_values('frequency', ascending=False )

active_stations_df
# Out:
#              frequency
# station
# USC00519281       2772
# USC00519397       2724
# USC00513117       2709
# USC00519523       2669
# USC00516128       2612
# USC00514830       2202
# USC00511918       1979
# USC00517948       1372
# USC00518838        511

# %%
most_active_station = active_stations_df.index[0]

most_active_station_df = pd.DataFrame(session.query(station.station, station.name).filter(station.station == most_active_station).all(), columns=["station", "name"])
name_of_most_active_station =  most_active_station_df.loc[0, "name"]
name_of_most_active_station
# Out:
# 'WAIHEE 837.5, HI US'

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.

temp_most_active_station = session.query(measurement.station, measurement.date, measurement.tobs).\
                            filter(measurement.station == most_active_station).all()
temp_most_active_station
# Out:
# [('USC00519281', '2010-01-01', 70.0),
#  ('USC00519281', '2010-01-02', 62.0),
#  ('USC00519281', '2010-01-03', 74.0),
#  ('USC00519281', '2010-01-04', 75.0),
#  ('USC00519281', '2010-01-05', 74.0),
#  ('USC00519281', '2010-01-06', 76.0),
#  ('USC00519281', '2010-01-07', 69.0),
#  ('USC00519281', '2010-01-08', 66.0),
#  ('USC00519281', '2010-01-09', 70.0),
#  ('USC00519281', '2010-01-10', 75.0),
#  ('USC00519281', '2010-01-11', 64.0),
#  ('USC00519281', '2010-01-12', 60.0),
#  ('USC00519281', '2010-01-13', 61.0),
#  ('USC00519281', '2010-01-14', 68.0),
#  ('USC00519281', '2010-01-15', 64.0),
#  ('USC00519281', '2010-01-16', 66.0),
#  ('USC00519281', '2010-01-17', 67.0),
#  ('USC00519281', '2010-01-18', 70.0),
#  ('USC00519281', '2010-01-19', 67.0),
#  ('USC00519281', '2010-01-20', 67.0),
#  ('USC00519281', '2010-01-21', 69.0),
#  ('USC00519281', '2010-01-22', 60.0),
#  ('USC00519281', '2010-01-23', 75.0),
#  ('USC00519281', '2010-01-24', 75.0),
#  ('USC00519281', '2010-01-25', 65.0),
# ...

# %%
temperature_DF = pd.DataFrame(temp_most_active_station, columns=['station', 'date', 'tobs'])

print(f"The temperature at the the most active station {name_of_most_active_station} ({most_active_station}) can be summarised as follows:")
print(f"minimum {temperature_DF['tobs'].min()}, maximum {temperature_DF['tobs'].max()}, and average {temperature_DF['tobs'].mean()}.")
# Out:
# The temperature at the the most active station WAIHEE 837.5, HI US (USC00519281) can be summarised as follows:
# minimum 54.0, maximum 85.0, and average 71.66378066378067.

# %%
# Using the most active station id



# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

most_recent_temp = dt.datetime.strftime(most_rec, '%Y-%m-%d')

print(most_recent_temp)

histo_data = temperature_DF.loc[(temperature_DF.date > most_recent_temp)]


plt.hist(histo_data['tobs'].tolist(), bins=12)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title(f'Distribution of temperatures at station {name_of_most_active_station}')
# Out:
# 2016-08-23
# Text(0.5, 1.0, 'Distribution of temperatures at station WAIHEE 837.5, HI US')

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
